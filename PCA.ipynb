# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_context("talk")
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.preprocessing import MaxAbsScaler, Normalizer, StandardScaler, RobustScaler
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import ConfusionMatrix

# %matplotlib inline

# %%
# Read in data frame from EDA
df = pd.read_pickle('df_ready1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2814 entries, 3 to 3194
# Data columns (total 63 columns):
# State FIPS Code                                                         2814 non-null object
# County FIPS Code                                                        2814 non-null object
# 5-digit FIPS Code                                                       2814 non-null object
# State Abbreviation                                                      2814 non-null object
# Name                                                                    2814 non-null object
# County Ranked (Yes=1/No=0)                                              2814 non-null object
# Premature death raw value                                               2814 non-null object
# Poor or fair health raw value                                           2814 non-null float64
# Poor physical health days raw value                                     2814 non-null float64
# Poor mental health days raw value                                       2814 non-null float64
# Adult smoking raw value                                                 2814 non-null float64
# Adult obesity raw value                                                 2814 non-null float64
# Food environment index raw value                                        2814 non-null float64
# Physical inactivity raw value                                           2814 non-null float64
# Access to exercise opportunities raw value                              2814 non-null float64
# Excessive drinking raw value                                            2814 non-null float64
# Alcohol-impaired driving deaths raw value                               2814 non-null float64
# Uninsured raw value                                                     2814 non-null float64
# Dentists raw value                                                      2814 non-null float64
# Preventable hospital stays raw value                                    2814 non-null float64
# Mammography screening raw value                                         2814 non-null float64
# Flu vaccinations raw value                                              2814 non-null float64
# High school graduation raw value                                        2814 non-null float64
# Some college raw value                                                  2814 non-null float64
# Unemployment raw value                                                  2814 non-null float64
# Children in poverty raw value                                           2814 non-null float64
# Income inequality raw value                                             2814 non-null float64
# Children in single-parent households raw value                          2814 non-null float64
# Social associations raw value                                           2814 non-null float64
# Air pollution - particulate matter raw value                            2814 non-null float64
# Drinking water violations raw value                                     2814 non-null float64
# Severe housing problems raw value                                       2814 non-null float64
# Percentage of households with high housing costs                        2814 non-null float64
# Percentage of households with overcrowding                              2814 non-null float64
# Percentage of households with lack of kitchen or plumbing facilities    2814 non-null float64
# Driving alone to work raw value                                         2814 non-null float64
# Long commute - driving alone raw value                                  2814 non-null float64
# Life expectancy raw value                                               2814 non-null float64
# Premature age-adjusted mortality raw value                              2814 non-null float64
# Frequent physical distress raw value                                    2814 non-null float64
# Frequent mental distress raw value                                      2814 non-null float64
# Diabetes prevalence raw value                                           2814 non-null float64
# Food insecurity raw value                                               2814 non-null float64
# Limited access to healthy foods raw value                               2814 non-null float64
# Insufficient sleep raw value                                            2814 non-null float64
# Uninsured adults raw value                                              2814 non-null float64
# Uninsured children raw value                                            2814 non-null float64
# Other primary care providers raw value                                  2814 non-null float64
# Median household income raw value                                       2814 non-null float64
# Homeownership raw value                                                 2814 non-null float64
# Severe housing cost burden raw value                                    2814 non-null float64
# Population raw value                                                    2814 non-null float64
# % below 18 years of age raw value                                       2814 non-null float64
# % 65 and older raw value                                                2814 non-null float64
# % Non-Hispanic African American raw value                               2814 non-null float64
# % American Indian and Alaskan Native raw value                          2814 non-null float64
# % Asian raw value                                                       2814 non-null float64
# % Native Hawaiian/Other Pacific Islander raw value                      2814 non-null float64
# % Hispanic raw value                                                    2814 non-null float64
# % Non-Hispanic white raw value                                          2814 non-null float64
# % not proficient in English raw value                                   2814 non-null float64
# % Females raw value                                                     2814 non-null float64
# % Rural raw value                                                       2814 non-null float64
# dtypes: float64(56), object(7)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#   State FIPS Code County FIPS Code 5-digit FIPS Code State Abbreviation  \
# 3              01              001             01001                 AL
# 4              01              003             01003                 AL
# 5              01              005             01005                 AL
# 6              01              007             01007                 AL
# 7              01              009             01009                 AL
#
#              Name County Ranked (Yes=1/No=0) Premature death raw value  \
# 3  Autauga County                          1              8824.0571232
# 4  Baldwin County                          1              7224.6321603
# 5  Barbour County                          1               9586.165037
# 6     Bibb County                          1              11783.543675
# 7   Blount County                          1              10908.101822
#
#    Poor or fair health raw value  Poor physical health days raw value  \
# 3                       0.184111                             4.200578
# 4                       0.180605                             4.098748
# 5                       0.257734                             5.067438
# 6                       0.199969                             4.363377
# 7                       0.210953                             4.512753
#
#    Poor mental health days raw value  ...  % 65 and older raw value  \
# 3                           4.306739  ...                  0.151196
# 4                           4.249649  ...                  0.199470
# 5                           4.634994  ...                  0.188247
# 6                           4.315710  ...                  0.160226
# 7                           4.701599  ...                  0.178426
#
#    % Non-Hispanic African American raw value  \
# 3                                   0.192545
# 4                                   0.089532
# 5                                   0.479422
# 6                                   0.214576
# 7                                   0.014600
#
#    % American Indian and Alaskan Native raw value  % Asian raw value  \
# 3                                        0.004756           0.012792
# 4                                        0.007760           0.011565
# 5                                        0.006529           0.004630
# 6                                        0.004279           0.002206
# 7                                        0.006326           0.003017
#
#    % Native Hawaiian/Other Pacific Islander raw value  % Hispanic raw value  \
# 3                                           0.001045               0.028575
# 4                                           0.000687               0.045502
# 5                                           0.001860               0.042066
# 6                                           0.001147               0.026381
# 7                                           0.001172               0.095651
#
#    % Non-Hispanic white raw value  % not proficient in English raw value  \
# 3                        0.744739                               0.008285
# 4                        0.830474                               0.004545
# 5                        0.459557                               0.011993
# 6                        0.742986                               0.003943
# 7                        0.869443                               0.018700
#
#    % Females raw value  % Rural raw value
# 3             0.513422           0.420022
# 4             0.514528           0.422791
# 5             0.472299           0.677896
# 6             0.464531           0.683526
# 7             0.506886           0.899515
#
# [5 rows x 63 columns]

# %%
# View all column topics
list(df.columns)
# Out:
# ['State FIPS Code',
#  'County FIPS Code',
#  '5-digit FIPS Code',
#  'State Abbreviation',
#  'Name',
#  'County Ranked (Yes=1/No=0)',
#  'Premature death raw value',
#  'Poor or fair health raw value',
#  'Poor physical health days raw value',
#  'Poor mental health days raw value',
#  'Adult smoking raw value',
#  'Adult obesity raw value',
#  'Food environment index raw value',
#  'Physical inactivity raw value',
#  'Access to exercise opportunities raw value',
#  'Excessive drinking raw value',
#  'Alcohol-impaired driving deaths raw value',
#  'Uninsured raw value',
#  'Dentists raw value',
#  'Preventable hospital stays raw value',
#  'Mammography screening raw value',
#  'Flu vaccinations raw value',
#  'High school graduation raw value',
#  'Some college raw value',
#  'Unemployment raw value',
#  'Children in poverty raw value',
#  'Income inequality raw value',
#  'Children in single-parent households raw value',
#  'Social associations raw value',
#  'Air pollution - particulate matter raw value',
#  'Drinking water violations raw value',
#  'Severe housing problems raw value',
#  'Percentage of households with high housing costs',
#  'Percentage of households with overcrowding',
#  'Percentage of households with lack of kitchen or plumbing facilities',
#  'Driving alone to work raw value',
#  'Long commute - driving alone raw value',
#  'Life expectancy raw value',
#  'Premature age-adjusted mortality raw value',
#  'Frequent physical distress raw value',
#  'Frequent mental distress raw value',
#  'Diabetes prevalence raw value',
#  'Food insecurity raw value',
#  'Limited access to healthy foods raw value',
#  'Insufficient sleep raw value',
#  'Uninsured adults raw value',
#  'Uninsured children raw value',
#  'Other primary care providers raw value',
#  'Median household income raw value',
#  'Homeownership raw value',
#  'Severe housing cost burden raw value',
#  'Population raw value',
#  '% below 18 years of age raw value',
#  '% 65 and older raw value',
#  '% Non-Hispanic African American raw value',
#  '% American Indian and Alaskan Native raw value',
#  '% Asian raw value',
#  '% Native Hawaiian/Other Pacific Islander raw value',
#  '% Hispanic raw value',
#  '% Non-Hispanic white raw value',
#  '% not proficient in English raw value',
#  '% Females raw value',
#  '% Rural raw value']

# %%
df['target'] = 0 # create a target column

# %%
# Looking at the target variable distribution
sns.distplot(df['High school graduation raw value'])

# %%
plt.hist(df['High school graduation raw value'])
# Out:
# (array([   3.,    2.,    6.,    6.,   19.,   87.,  214.,  723., 1099.,
#          655.]),
#  array([0.3630137 , 0.42671233, 0.49041096, 0.55410959, 0.61780822,
#         0.68150685, 0.74520548, 0.80890411, 0.87260274, 0.93630137,
#         1.        ]),
#  <a list of 10 Patch objects>)

# %%
# Setting mock federal standard for a highschool grad rate of at least 90%
df.loc[df['High school graduation raw value'] >= 0.9, 'target'] = 1  # Meeting standard

df.loc[df['High school graduation raw value'] <0.9, 'target'] = 0  # Failing to meet standard

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr())

# %%
0.21697799347796504, % rural 
 0.2719691482359243, Home ownership
 0.31094167052019217, % Non-Hispanic white raw value
 0.7300252065326511
    
 -0.32083586573184425, Children in single-parent households raw value
 -0.31468499753911716, Severe housing problems raw value
 -0.30586254195786583, Percentage of households with high housing costs
 -0.3017989466551982,
 -0.24732405190486392,

# %%
df.corr()[df.corr()['target'] == -0.30586254195786583]
# Out:
#                                                   Poor or fair health raw value  \
# Percentage of households with high housing costs                       0.179709
#
#                                                   Poor physical health days raw value  \
# Percentage of households with high housing costs                             0.177796
#
#                                                   Poor mental health days raw value  \
# Percentage of households with high housing costs                            0.21235
#
#                                                   Adult smoking raw value  \
# Percentage of households with high housing costs                 0.041881
#
#                                                   Adult obesity raw value  \
# Percentage of households with high housing costs                -0.230211
#
#                                                   Food environment index raw value  \
# Percentage of households with high housing costs                         -0.207124
#
#                                                   Physical inactivity raw value  \
# Percentage of households with high housing costs                      -0.171708
#
#                                                   Access to exercise opportunities raw value  \
# Percentage of households with high housing costs                                    0.280687
#
#                                                   Excessive drinking raw value  \
# Percentage of households with high housing costs                     -0.026531
#
#                                                   Alcohol-impaired driving deaths raw value  \
# Percentage of households with high housing costs                                  -0.004409
#
#                                                   ...  \
# Percentage of households with high housing costs  ...
#
#                                                   % Non-Hispanic African American raw value  \
# Percentage of households with high housing costs                                    0.37322
#
#                                                   % American Indian and Alaskan Native raw value  \
# Percentage of households with high housing costs                                       -0.044272
#
#                                                   % Asian raw value  \
# Percentage of households with high housing costs           0.363384
#
#                                                   % Native Hawaiian/Other Pacific Islander raw value  \
# Percentage of households with high housing costs                                           0.152582
#
#                                                   % Hispanic raw value  \
# Percentage of households with high housing costs               0.11189
#
#                                                   % Non-Hispanic white raw value  \
# Percentage of households with high housing costs                       -0.385083
#
#                                                   % not proficient in English raw value  \
# Percentage of households with high housing costs                               0.190879
#
#                                                   % Females raw value  \
# Percentage of households with high housing costs             0.193294
#
#                                                   % Rural raw value    target
# Percentage of households with high housing costs          -0.382717 -0.305863
#
# [1 rows x 57 columns]

# %%
df.corr()
# Out:
#                                                     Poor or fair health raw value  \
# Poor or fair health raw value                                            1.000000
# Poor physical health days raw value                                      0.878801
# Poor mental health days raw value                                        0.744368
# Adult smoking raw value                                                  0.726499
# Adult obesity raw value                                                  0.462766
# Food environment index raw value                                        -0.592937
# Physical inactivity raw value                                            0.600402
# Access to exercise opportunities raw value                              -0.383742
# Excessive drinking raw value                                            -0.668137
# Alcohol-impaired driving deaths raw value                               -0.069254
# Uninsured raw value                                                      0.460794
# Dentists raw value                                                      -0.275714
# Preventable hospital stays raw value                                     0.456444
# Mammography screening raw value                                         -0.494157
# Flu vaccinations raw value                                              -0.329394
# High school graduation raw value                                        -0.148569
# Some college raw value                                                  -0.675106
# Unemployment raw value                                                   0.550708
# Children in poverty raw value                                            0.840837
# Income inequality raw value                                              0.553210
# Children in single-parent households raw value                           0.624632
# Social associations raw value                                           -0.247039
# Air pollution - particulate matter raw value                             0.245644
# Drinking water violations raw value                                      0.028038
# Severe housing problems raw value                                        0.313552
# Percentage of households with high housing costs                         0.179709
# Percentage of households with overcrowding                               0.399548
# Percentage of households with lack of kitchen o...                       0.116495
# Driving alone to work raw value                                          0.176461
# Long commute - driving alone raw value                                   0.063677
# Life expectancy raw value                                               -0.660540
# Premature age-adjusted mortality raw value                               0.724160
# Frequent physical distress raw value                                     0.928585
# Frequent mental distress raw value                                       0.844810
# Diabetes prevalence raw value                                            0.622548
# Food insecurity raw value                                                0.680119
# Limited access to healthy foods raw value                                0.209466
# Insufficient sleep raw value                                             0.654613
# Uninsured adults raw value                                               0.511723
# Uninsured children raw value                                             0.124868
# Other primary care providers raw value                                  -0.044473
# Median household income raw value                                       -0.683853
# Homeownership raw value                                                 -0.245673
# Severe housing cost burden raw value                                     0.224872
# Population raw value                                                    -0.081247
# % below 18 years of age raw value                                        0.159493
# % 65 and older raw value                                                -0.117206
# % Non-Hispanic African American raw value                                0.460310
# % American Indian and Alaskan Native raw value                           0.159925
# % Asian raw value                                                       -0.192866
# % Native Hawaiian/Other Pacific Islander raw value                      -0.013581
# % Hispanic raw value                                                     0.252089
# % Non-Hispanic white raw value                                          -0.526736
# % not proficient in English raw value                                    0.204668
# % Females raw value                                                      0.016288
# % Rural raw value                                                        0.129470
# target                                                                  -0.117236
#
#                                                     Poor physical health days raw value  \
# Poor or fair health raw value                                                  0.878801
# Poor physical health days raw value                                            1.000000
# Poor mental health days raw value                                              0.918575
# Adult smoking raw value                                                        0.807517
# Adult obesity raw value                                                        0.434351
# Food environment index raw value                                              -0.527775
# Physical inactivity raw value                                                  0.580096
# Access to exercise opportunities raw value                                    -0.351897
# Excessive drinking raw value                                                  -0.650360
# Alcohol-impaired driving deaths raw value                                     -0.035508
# Uninsured raw value                                                            0.275711
# Dentists raw value                                                            -0.246077
# Preventable hospital stays raw value                                           0.407049
# Mammography screening raw value                                               -0.438488
# Flu vaccinations raw value                                                    -0.266958
# High school graduation raw value                                              -0.118059
# Some college raw value                                                        -0.635858
# Unemployment raw value                                                         0.551006
# Children in poverty raw value                                                  0.761404
# Income inequality raw value                                                    0.474319
# Children in single-parent households raw value                                 0.534643
# Social associations raw value                                                 -0.299657
# Air pollution - particulate matter raw value                                   0.280452
# Drinking water violations raw value                                            0.038347
# Severe housing problems raw value                                              0.254230
# Percentage of households with high housing costs                               0.177796
# Percentage of households with overcrowding                                     0.237068
# Percentage of households with lack of kitchen o...                             0.121905
# Driving alone to work raw value                                                0.193170
# Long commute - driving alone raw value                                         0.116424
# Life expectancy raw value                                                     -0.684337
# Premature age-adjusted mortality raw value                                     0.729830
# Frequent physical distress raw value                                           0.982399
# Frequent mental distress raw value                                             0.950778
# Diabetes prevalence raw value                                                  0.660604
# Food insecurity raw value                                                      0.639451
# Limited access to healthy foods raw value                                      0.145022
# Insufficient sleep raw value                                                   0.683793
# Uninsured adults raw value                                                     0.317399
# Uninsured children raw value                                                  -0.018604
# Other primary care providers raw value                                        -0.014693
# Median household income raw value                                             -0.665979
# Homeownership raw value                                                       -0.159737
# Severe housing cost burden raw value                                           0.199217
# Population raw value                                                          -0.113749
# % below 18 years of age raw value                                              0.009942
# % 65 and older raw value                                                      -0.016581
# % Non-Hispanic African American raw value                                      0.284450
# % American Indian and Alaskan Native raw value                                 0.193063
# % Asian raw value                                                             -0.236115
# % Native Hawaiian/Other Pacific Islander raw value                            -0.023684
# % Hispanic raw value                                                          -0.004908
# % Non-Hispanic white raw value                                                -0.235156
# % not proficient in English raw value                                         -0.027721
# % Females raw value                                                            0.055813
# % Rural raw value                                                              0.176699
# target                                                                        -0.094063
#
#                                                     Poor mental health days raw value  \
# Poor or fair health raw value                                                0.744368
# Poor physical health days raw value                                          0.918575
# Poor mental health days raw value                                            1.000000
# Adult smoking raw value                                                      0.759394
# Adult obesity raw value                                                      0.419075
# Food environment index raw value                                            -0.447015
# Physical inactivity raw value                                                0.541855
# Access to exercise opportunities raw value                                  -0.280632
# Excessive drinking raw value                                                -0.616353
# Alcohol-impaired driving deaths raw value                                   -0.040234
# Uninsured raw value                                                          0.152654
# Dentists raw value                                                          -0.196485
# Preventable hospital stays raw value                                         0.339211
# Mammography screening raw value                                             -0.353863
# Flu vaccinations raw value                                                  -0.140905
# High school graduation raw value                                            -0.120862
# Some college raw value                                                      -0.541711
# Unemployment raw value                                                       0.482194
# Children in poverty raw value                                                0.642998
# Income inequality raw value                                                  0.419130
# Children in single-parent households raw value                               0.491318
# Social associations raw value                                               -0.315161
# Air pollution - particulate matter raw value                                 0.330551
# Drinking water violations raw value                                          0.053662
# Severe housing problems raw value                                            0.233309
# Percentage of households with high housing costs                             0.212350
# Percentage of households with overcrowding                                   0.114635
# Percentage of households with lack of kitchen o...                           0.087653
# Driving alone to work raw value                                              0.221837
# Long commute - driving alone raw value                                       0.176802
# Life expectancy raw value                                                   -0.647474
# Premature age-adjusted mortality raw value                                   0.674936
# Frequent physical distress raw value                                         0.879821
# Frequent mental distress raw value                                           0.956017
# Diabetes prevalence raw value                                                0.667693
# Food insecurity raw value                                                    0.596266
# Limited access to healthy foods raw value                                    0.055647
# Insufficient sleep raw value                                                 0.692852
# Uninsured adults raw value                                                   0.190100
# Uninsured children raw value                                                -0.131277
# Other primary care providers raw value                                       0.012110
# Median household income raw value                                           -0.569563
# Homeownership raw value                                                     -0.129632
# Severe housing cost burden raw value                                         0.220450
# Population raw value                                                        -0.084121
# % below 18 years of age raw value                                           -0.090007
# % 65 and older raw value                                                     0.019297
# % Non-Hispanic African American raw value                                    0.267124
# % American Indian and Alaskan Native raw value                               0.141413
# % Asian raw value                                                           -0.204566
# % Native Hawaiian/Other Pacific Islander raw value                          -0.024244
# % Hispanic raw value                                                        -0.148833
# % Non-Hispanic white raw value                                              -0.115947
# % not proficient in English raw value                                       -0.137634
# % Females raw value                                                          0.160337
# % Rural raw value                                                            0.143533
# target                                                                      -0.108632
#
#                                                     Adult smoking raw value  \
# Poor or fair health raw value                                      0.726499
# Poor physical health days raw value                                0.807517
# Poor mental health days raw value                                  0.759394
# Adult smoking raw value                                            1.000000
# Adult obesity raw value                                            0.595126
# Food environment index raw value                                  -0.461782
# Physical inactivity raw value                                      0.660938
# Access to exercise opportunities raw value                        -0.383809
# Excessive drinking raw value                                      -0.482819
# Alcohol-impaired driving deaths raw value                         -0.006686
# Uninsured raw value                                                0.150630
# Dentists raw value                                                -0.276907
# Preventable hospital stays raw value                               0.474413
# Mammography screening raw value                                   -0.277638
# Flu vaccinations raw value                                        -0.178881
# High school graduation raw value                                  -0.049125
# Some college raw value                                            -0.556254
# Unemployment raw value                                             0.410380
# Children in poverty raw value                                      0.660172
# Income inequality raw value                                        0.375049
# Children in single-parent households raw value                     0.511007
# Social associations raw value                                     -0.144468
# Air pollution - particulate matter raw value                       0.318065
# Drinking water violations raw value                               -0.072955
# Severe housing problems raw value                                  0.059115
# Percentage of households with high housing costs                   0.041881
# Percentage of households with overcrowding                         0.052612
# Percentage of households with lack of kitchen o...                 0.065581
# Driving alone to work raw value                                    0.282313
# Long commute - driving alone raw value                             0.108120
# Life expectancy raw value                                         -0.722593
# Premature age-adjusted mortality raw value                         0.737948
# Frequent physical distress raw value                               0.811792
# Frequent mental distress raw value                                 0.822048
# Diabetes prevalence raw value                                      0.675669
# Food insecurity raw value                                          0.585571
# Limited access to healthy foods raw value                          0.094244
# Insufficient sleep raw value                                       0.662502
# Uninsured adults raw value                                         0.188809
# Uninsured children raw value                                      -0.094542
# Other primary care providers raw value                             0.023034
# Median household income raw value                                 -0.632211
# Homeownership raw value                                           -0.112956
# Severe housing cost burden raw value                               0.060978
# Population raw value                                              -0.213112
# % below 18 years of age raw value                                  0.028673
# % 65 and older raw value                                          -0.080322
# % Non-Hispanic African American raw value                          0.302138
# % American Indian and Alaskan Native raw value                     0.208616
# % Asian raw value                                                 -0.340050
# % Native Hawaiian/Other Pacific Islander raw value                -0.154003
# % Hispanic raw value                                              -0.285027
# % Non-Hispanic white raw value                                    -0.045828
# % not proficient in English raw value                             -0.255960
# % Females raw value                                                0.018622
# % Rural raw value                                                  0.252783
# target                                                            -0.023481
#
#                                                     Adult obesity raw value  \
# Poor or fair health raw value                                      0.462766
# Poor physical health days raw value                                0.434351
# Poor mental health days raw value                                  0.419075
# Adult smoking raw value                                            0.595126
# Adult obesity raw value                                            1.000000
# Food environment index raw value                                  -0.318802
# Physical inactivity raw value                                      0.697498
# Access to exercise opportunities raw value                        -0.394099
# Excessive drinking raw value                                      -0.397771
# Alcohol-impaired driving deaths raw value                         -0.005061
# Uninsured raw value                                                0.046772
# Dentists raw value                                                -0.319737
# Preventable hospital stays raw value                               0.403452
# Mammography screening raw value                                   -0.092901
# Flu vaccinations raw value                                        -0.128988
# High school graduation raw value                                   0.032604
# Some college raw value                                            -0.407586
# Unemployment raw value                                             0.251903
# Children in poverty raw value                                      0.412483
# Income inequality raw value                                        0.119028
# Children in single-parent households raw value                     0.341653
# Social associations raw value                                      0.095615
# Air pollution - particulate matter raw value                       0.304526
# Drinking water violations raw value                               -0.105417
# Severe housing problems raw value                                 -0.222093
# Percentage of households with high housing costs                  -0.230211
# Percentage of households with overcrowding                        -0.061749
# Percentage of households with lack of kitchen o...                 0.005300
# Driving alone to work raw value                                    0.403842
# Long commute - driving alone raw value                             0.069691
# Life expectancy raw value                                         -0.580479
# Premature age-adjusted mortality raw value                         0.551585
# Frequent physical distress raw value                               0.441468
# Frequent mental distress raw value                                 0.461997
# Diabetes prevalence raw value                                      0.678225
# Food insecurity raw value                                          0.398605
# Limited access to healthy foods raw value                          0.072889
# Insufficient sleep raw value                                       0.449843
# Uninsured adults raw value                                         0.082314
# Uninsured children raw value                                      -0.112969
# Other primary care providers raw value                            -0.041661
# Median household income raw value                                 -0.487066
# Homeownership raw value                                            0.106723
# Severe housing cost burden raw value                              -0.212645
# Population raw value                                              -0.260676
# % below 18 years of age raw value                                  0.168584
# % 65 and older raw value                                          -0.030261
# % Non-Hispanic African American raw value                          0.323747
# % American Indian and Alaskan Native raw value                     0.074681
# % Asian raw value                                                 -0.373937
# % Native Hawaiian/Other Pacific Islander raw value                -0.145916
# % Hispanic raw value                                              -0.299240
# % Non-Hispanic white raw value                                    -0.003475
# % not proficient in English raw value                             -0.254401
# % Females raw value                                                0.071615
# % Rural raw value                                                  0.270408
# target                                                             0.019938
#
#                                                     Food environment index raw value  \
# Poor or fair health raw value                                              -0.592937
# Poor physical health days raw value                                        -0.527775
# Poor mental health days raw value                                          -0.447015
# Adult smoking raw value                                                    -0.461782
# Adult obesity raw value                                                    -0.318802
# Food environment index raw value                                            1.000000
# Physical inactivity raw value                                              -0.367152
# Access to exercise opportunities raw value                                  0.304014
# Excessive drinking raw value                                                0.464623
# Alcohol-impaired driving deaths raw value                                  -0.007105
# Uninsured raw value                                                        -0.365263
# Dentists raw value                                                          0.103126
# Preventable hospital stays raw value                                       -0.252664
# Mammography screening raw value                                             0.326891
# Flu vaccinations raw value                                                  0.350901
# High school graduation raw value                                            0.246196
# Some college raw value                                                      0.334405
# Unemployment raw value                                                     -0.420981
# Children in poverty raw value                                              -0.687354
# Income inequality raw value                                                -0.487047
# Children in single-parent households raw value                             -0.569755
# Social associations raw value                                               0.077369
# Air pollution - particulate matter raw value                               -0.004742
# Drinking water violations raw value                                        -0.038707
# Severe housing problems raw value                                          -0.277685
# Percentage of households with high housing costs                           -0.207124
# Percentage of households with overcrowding                                 -0.212900
# Percentage of households with lack of kitchen o...                         -0.197767
# Driving alone to work raw value                                            -0.012271
# Long commute - driving alone raw value                                      0.113889
# Life expectancy raw value                                                   0.493198
# Premature age-adjusted mortality raw value                                 -0.564814
# Frequent physical distress raw value                                       -0.588208
# Frequent mental distress raw value                                         -0.570588
# Diabetes prevalence raw value                                              -0.418372
# Food insecurity raw value                                                  -0.834408
# Limited access to healthy foods raw value                                  -0.735414
# Insufficient sleep raw value                                               -0.324372
# Uninsured adults raw value                                                 -0.392129
# Uninsured children raw value                                               -0.143963
# Other primary care providers raw value                                     -0.065096
# Median household income raw value                                           0.580809
# Homeownership raw value                                                     0.316251
# Severe housing cost burden raw value                                       -0.249131
# Population raw value                                                        0.093074
# % below 18 years of age raw value                                          -0.035349
# % 65 and older raw value                                                   -0.007563
# % Non-Hispanic African American raw value                                  -0.517735
# % American Indian and Alaskan Native raw value                             -0.266778
# % Asian raw value                                                           0.162222
# % Native Hawaiian/Other Pacific Islander raw value                          0.012178
# % Hispanic raw value                                                        0.030577
# % Non-Hispanic white raw value                                              0.419241
# % not proficient in English raw value                                       0.085527
# % Females raw value                                                        -0.016617
# % Rural raw value                                                          -0.082065
# target                                                                      0.185029
#
#                                                     Physical inactivity raw value  \
# Poor or fair health raw value                                            0.600402
# Poor physical health days raw value                                      0.580096
# Poor mental health days raw value                                        0.541855
# Adult smoking raw value                                                  0.660938
# Adult obesity raw value                                                  0.697498
# Food environment index raw value                                        -0.367152
# Physical inactivity raw value                                            1.000000
# Access to exercise opportunities raw value                              -0.484713
# Excessive drinking raw value                                            -0.573041
# Alcohol-impaired driving deaths raw value                               -0.080190
# Uninsured raw value                                                      0.263735
# Dentists raw value                                                      -0.393503
# Preventable hospital stays raw value                                     0.496344
# Mammography screening raw value                                         -0.263773
# Flu vaccinations raw value                                              -0.218386
# High school graduation raw value                                         0.083440
# Some college raw value                                                  -0.555455
# Unemployment raw value                                                   0.283198
# Children in poverty raw value                                            0.545381
# Income inequality raw value                                              0.224353
# Children in single-parent households raw value                           0.352792
# Social associations raw value                                            0.073508
# Air pollution - particulate matter raw value                             0.337356
# Drinking water violations raw value                                     -0.089552
# Severe housing problems raw value                                       -0.156272
# Percentage of households with high housing costs                        -0.171708
# Percentage of households with overcrowding                              -0.029126
# Percentage of households with lack of kitchen o...                       0.021695
# Driving alone to work raw value                                          0.348249
# Long commute - driving alone raw value                                   0.161042
# Life expectancy raw value                                               -0.677912
# Premature age-adjusted mortality raw value                               0.691165
# Frequent physical distress raw value                                     0.581191
# Frequent mental distress raw value                                       0.580740
# Diabetes prevalence raw value                                            0.765046
# Food insecurity raw value                                                0.483130
# Limited access to healthy foods raw value                                0.054091
# Insufficient sleep raw value                                             0.511428
# Uninsured adults raw value                                               0.286234
# Uninsured children raw value                                             0.063192
# Other primary care providers raw value                                  -0.082890
# Median household income raw value                                       -0.589782
# Homeownership raw value                                                  0.124438
# Severe housing cost burden raw value                                    -0.145330
# Population raw value                                                    -0.224046
# % below 18 years of age raw value                                        0.060431
# % 65 and older raw value                                                 0.112544
# % Non-Hispanic African American raw value                                0.310805
# % American Indian and Alaskan Native raw value                          -0.005636
# % Asian raw value                                                       -0.359596
# % Native Hawaiian/Other Pacific Islander raw value                      -0.172581
# % Hispanic raw value                                                    -0.234807
# % Non-Hispanic white raw value                                          -0.013670
# % not proficient in English raw value                                   -0.200860
# % Females raw value                                                      0.087902
# % Rural raw value                                                        0.363888
# target                                                                   0.068713
#
#                                                     Access to exercise opportunities raw value  \
# Poor or fair health raw value                                                        -0.383742
# Poor physical health days raw value                                                  -0.351897
# Poor mental health days raw value                                                    -0.280632
# Adult smoking raw value                                                              -0.383809
# Adult obesity raw value                                                              -0.394099
# Food environment index raw value                                                      0.304014
# Physical inactivity raw value                                                        -0.484713
# Access to exercise opportunities raw value                                            1.000000
# Excessive drinking raw value                                                          0.395038
# Alcohol-impaired driving deaths raw value                                             0.001339
# Uninsured raw value                                                                  -0.287765
# Dentists raw value                                                                    0.439269
# Preventable hospital stays raw value                                                 -0.306061
# Mammography screening raw value                                                       0.223716
# Flu vaccinations raw value                                                            0.311602
# High school graduation raw value                                                     -0.110087
# Some college raw value                                                                0.474720
# Unemployment raw value                                                               -0.167293
# Children in poverty raw value                                                        -0.393938
# Income inequality raw value                                                          -0.117705
# Children in single-parent households raw value                                       -0.153145
# Social associations raw value                                                        -0.101640
# Air pollution - particulate matter raw value                                         -0.065690
# Drinking water violations raw value                                                   0.090586
# Severe housing problems raw value                                                     0.195392
# Percentage of households with high housing costs                                      0.280687
# Percentage of households with overcrowding                                           -0.058573
# Percentage of households with lack of kitchen o...                                   -0.111866
# Driving alone to work raw value                                                      -0.147426
# Long commute - driving alone raw value                                               -0.198504
# Life expectancy raw value                                                             0.414539
# Premature age-adjusted mortality raw value                                           -0.433300
# Frequent physical distress raw value                                                 -0.366568
# Frequent mental distress raw value                                                   -0.344752
# Diabetes prevalence raw value                                                        -0.453365
# Food insecurity raw value                                                            -0.314197
# Limited access to healthy foods raw value                                            -0.149413
# Insufficient sleep raw value                                                         -0.195447
# Uninsured adults raw value                                                           -0.290489
# Uninsured children raw value                                                         -0.215629
# Other primary care providers raw value                                                0.193530
# Median household income raw value                                                     0.459218
# Homeownership raw value                                                              -0.280698
# Severe housing cost burden raw value                                                  0.256441
# Population raw value                                                                  0.301523
# % below 18 years of age raw value                                                    -0.076985
# % 65 and older raw value                                                             -0.143729
# % Non-Hispanic African American raw value                                            -0.185941
# % American Indian and Alaskan Native raw value                                       -0.106035
# % Asian raw value                                                                     0.382014
# % Native Hawaiian/Other Pacific Islander raw value                                    0.128110
# % Hispanic raw value                                                                  0.136749
# % Non-Hispanic white raw value                                                        0.017892
# % not proficient in English raw value                                                 0.184858
# % Females raw value                                                                   0.120179
# % Rural raw value                                                                    -0.594195
# target                                                                               -0.113876
#
#                                                     Excessive drinking raw value  \
# Poor or fair health raw value                                          -0.668137
# Poor physical health days raw value                                    -0.650360
# Poor mental health days raw value                                      -0.616353
# Adult smoking raw value                                                -0.482819
# Adult obesity raw value                                                -0.397771
# Food environment index raw value                                        0.464623
# Physical inactivity raw value                                          -0.573041
# Access to exercise opportunities raw value                              0.395038
# Excessive drinking raw value                                            1.000000
# Alcohol-impaired driving deaths raw value                               0.128864
# Uninsured raw value                                                    -0.369203
# Dentists raw value                                                      0.294788
# Preventable hospital stays raw value                                   -0.309732
# Mammography screening raw value                                         0.399911
# Flu vaccinations raw value                                              0.264827
# High school graduation raw value                                        0.042667
# Some college raw value                                                  0.515809
# Unemployment raw value                                                 -0.366135
# Children in poverty raw value                                          -0.608587
# Income inequality raw value                                            -0.308545
# Children in single-parent households raw value                         -0.371024
# Social associations raw value                                           0.093801
# Air pollution - particulate matter raw value                           -0.159791
# Drinking water violations raw value                                    -0.015091
# Severe housing problems raw value                                      -0.083805
# Percentage of households with high housing costs                       -0.026531
# Percentage of households with overcrowding                             -0.136255
# Percentage of households with lack of kitchen o...                     -0.075413
# Driving alone to work raw value                                        -0.207026
# Long commute - driving alone raw value                                 -0.131679
# Life expectancy raw value                                               0.572990
# Premature age-adjusted mortality raw value                             -0.617341
# Frequent physical distress raw value                                   -0.664563
# Frequent mental distress raw value                                     -0.667078
# Diabetes prevalence raw value                                          -0.661484
# Food insecurity raw value                                              -0.544028
# Limited access to healthy foods raw value                              -0.152372
# Insufficient sleep raw value                                           -0.451024
# Uninsured adults raw value                                             -0.399470
# Uninsured children raw value                                           -0.104139
# Other primary care providers raw value                                  0.036507
# Median household income raw value                                       0.534204
# Homeownership raw value                                                -0.014898
# Severe housing cost burden raw value                                   -0.050625
# Population raw value                                                    0.123970
# % below 18 years of age raw value                                      -0.073296
# % 65 and older raw value                                               -0.163349
# % Non-Hispanic African American raw value                              -0.350682
# % American Indian and Alaskan Native raw value                         -0.053605
# % Asian raw value                                                       0.197250
# % Native Hawaiian/Other Pacific Islander raw value                     -0.006005
# % Hispanic raw value                                                    0.015247
# % Non-Hispanic white raw value                                          0.235388
# % not proficient in English raw value                                   0.028441
# % Females raw value                                                    -0.181123
# % Rural raw value                                                      -0.275585
# target                                                                  0.045189
#
#                                                     Alcohol-impaired driving deaths raw value  \
# Poor or fair health raw value                                                       -0.069254
# Poor physical health days raw value                                                 -0.035508
# Poor mental health days raw value                                                   -0.040234
# Adult smoking raw value                                                             -0.006686
# Adult obesity raw value                                                             -0.005061
# Food environment index raw value                                                    -0.007105
# Physical inactivity raw value                                                       -0.080190
# Access to exercise opportunities raw value                                           0.001339
# Excessive drinking raw value                                                         0.128864
# Alcohol-impaired driving deaths raw value                                            1.000000
# Uninsured raw value                                                                 -0.111334
# Dentists raw value                                                                   0.050940
# Preventable hospital stays raw value                                                -0.048235
# Mammography screening raw value                                                      0.076948
# Flu vaccinations raw value                                                          -0.073278
# High school graduation raw value                                                    -0.027606
# Some college raw value                                                               0.060690
# Unemployment raw value                                                               0.045851
# Children in poverty raw value                                                       -0.014534
# Income inequality raw value                                                         -0.018478
# Children in single-parent households raw value                                      -0.010054
# Social associations raw value                                                        0.033592
# Air pollution - particulate matter raw value                                        -0.131848
# Drinking water violations raw value                                                  0.014449
# Severe housing problems raw value                                                   -0.016017
# Percentage of households with high housing costs                                    -0.004409
# Percentage of households with overcrowding                                          -0.038339
# Percentage of households with lack of kitchen o...                                   0.021820
# ...
# Unemployment raw value                                                           0.058424
# Children in poverty raw value                                                    0.039121
# Income inequality raw value                                                      0.076281
# Children in single-parent households raw value                                   0.013482
# Social associations raw value                                                   -0.198461
# Air pollution - particulate matter raw value                                    -0.063120
# Drinking water violations raw value                                              0.125400
# Severe housing problems raw value                                                0.405361
# Percentage of households with high housing costs                                 0.190879
# Percentage of households with overcrowding                                       0.636467
# Percentage of households with lack of kitchen o...                               0.032722
# Driving alone to work raw value                                                 -0.272351
# Long commute - driving alone raw value                                          -0.096109
# Life expectancy raw value                                                        0.239818
# Premature age-adjusted mortality raw value                                      -0.200436
# Frequent physical distress raw value                                             0.032301
# Frequent mental distress raw value                                              -0.095207
# Diabetes prevalence raw value                                                   -0.282761
# Food insecurity raw value                                                       -0.170718
# Limited access to healthy foods raw value                                        0.058304
# Insufficient sleep raw value                                                    -0.034194
# Uninsured adults raw value                                                       0.413330
# Uninsured children raw value                                                     0.312227
# Other primary care providers raw value                                          -0.055053
# Median household income raw value                                                0.110722
# Homeownership raw value                                                         -0.316830
# Severe housing cost burden raw value                                             0.196390
# Population raw value                                                             0.327056
# % below 18 years of age raw value                                                0.342538
# % 65 and older raw value                                                        -0.304926
# % Non-Hispanic African American raw value                                       -0.034446
# % American Indian and Alaskan Native raw value                                   0.001913
# % Asian raw value                                                                0.356499
# % Native Hawaiian/Other Pacific Islander raw value                               0.269111
# % Hispanic raw value                                                             0.826255
# % Non-Hispanic white raw value                                                  -0.581084
# % not proficient in English raw value                                            1.000000
# % Females raw value                                                             -0.091785
# % Rural raw value                                                               -0.352240
# target                                                                          -0.102636
#
#                                                     % Females raw value  \
# Poor or fair health raw value                                  0.016288
# Poor physical health days raw value                            0.055813
# Poor mental health days raw value                              0.160337
# Adult smoking raw value                                        0.018622
# Adult obesity raw value                                        0.071615
# Food environment index raw value                              -0.016617
# Physical inactivity raw value                                  0.087902
# Access to exercise opportunities raw value                     0.120179
# Excessive drinking raw value                                  -0.181123
# Alcohol-impaired driving deaths raw value                     -0.035467
# Uninsured raw value                                           -0.066424
# Dentists raw value                                             0.033451
# Preventable hospital stays raw value                           0.029375
# Mammography screening raw value                                0.135579
# Flu vaccinations raw value                                     0.196964
# High school graduation raw value                              -0.021601
# Some college raw value                                         0.239429
# Unemployment raw value                                         0.022709
# Children in poverty raw value                                  0.020064
# Income inequality raw value                                    0.132866
# Children in single-parent households raw value                 0.156023
# Social associations raw value                                  0.014911
# Air pollution - particulate matter raw value                   0.224477
# Drinking water violations raw value                           -0.006668
# Severe housing problems raw value                              0.124509
# Percentage of households with high housing costs               0.193294
# Percentage of households with overcrowding                    -0.059973
# Percentage of households with lack of kitchen o...            -0.054522
# Driving alone to work raw value                                0.129060
# Long commute - driving alone raw value                         0.070811
# Life expectancy raw value                                     -0.098267
# Premature age-adjusted mortality raw value                     0.066744
# Frequent physical distress raw value                           0.051920
# Frequent mental distress raw value                             0.144835
# Diabetes prevalence raw value                                  0.185944
# Food insecurity raw value                                      0.094071
# Limited access to healthy foods raw value                     -0.085884
# Insufficient sleep raw value                                   0.092209
# Uninsured adults raw value                                    -0.047461
# Uninsured children raw value                                  -0.172180
# Other primary care providers raw value                         0.119616
# Median household income raw value                              0.044356
# Homeownership raw value                                       -0.084956
# Severe housing cost burden raw value                           0.184469
# Population raw value                                           0.122631
# % below 18 years of age raw value                              0.152017
# % 65 and older raw value                                       0.060927
# % Non-Hispanic African American raw value                      0.146874
# % American Indian and Alaskan Native raw value                -0.027403
# % Asian raw value                                              0.084600
# % Native Hawaiian/Other Pacific Islander raw value            -0.041151
# % Hispanic raw value                                          -0.147599
# % Non-Hispanic white raw value                                -0.009780
# % not proficient in English raw value                         -0.091785
# % Females raw value                                            1.000000
# % Rural raw value                                             -0.156169
# target                                                        -0.037124
#
#                                                     % Rural raw value  \
# Poor or fair health raw value                                0.129470
# Poor physical health days raw value                          0.176699
# Poor mental health days raw value                            0.143533
# Adult smoking raw value                                      0.252783
# Adult obesity raw value                                      0.270408
# Food environment index raw value                            -0.082065
# Physical inactivity raw value                                0.363888
# Access to exercise opportunities raw value                  -0.594195
# Excessive drinking raw value                                -0.275585
# Alcohol-impaired driving deaths raw value                    0.063009
# Uninsured raw value                                          0.142535
# Dentists raw value                                          -0.452419
# Preventable hospital stays raw value                         0.142363
# Mammography screening raw value                             -0.111241
# Flu vaccinations raw value                                  -0.365196
# High school graduation raw value                             0.214760
# Some college raw value                                      -0.370329
# Unemployment raw value                                       0.094940
# Children in poverty raw value                                0.257343
# Income inequality raw value                                 -0.055766
# Children in single-parent households raw value              -0.071711
# Social associations raw value                                0.310016
# Air pollution - particulate matter raw value                -0.152005
# Drinking water violations raw value                         -0.142100
# Severe housing problems raw value                           -0.353335
# Percentage of households with high housing costs            -0.382717
# Percentage of households with overcrowding                  -0.147161
# Percentage of households with lack of kitchen o...           0.128699
# Driving alone to work raw value                              0.019014
# Long commute - driving alone raw value                       0.218649
# Life expectancy raw value                                   -0.260371
# Premature age-adjusted mortality raw value                   0.274975
# Frequent physical distress raw value                         0.179876
# Frequent mental distress raw value                           0.199024
# Diabetes prevalence raw value                                0.372488
# Food insecurity raw value                                    0.101125
# Limited access to healthy foods raw value                    0.020074
# Insufficient sleep raw value                                -0.046292
# Uninsured adults raw value                                   0.108919
# Uninsured children raw value                                 0.232643
# Other primary care providers raw value                      -0.181096
# Median household income raw value                           -0.430311
# Homeownership raw value                                      0.537077
# Severe housing cost burden raw value                        -0.369347
# Population raw value                                        -0.406013
# % below 18 years of age raw value                           -0.175295
# % 65 and older raw value                                     0.488906
# % Non-Hispanic African American raw value                   -0.093560
# % American Indian and Alaskan Native raw value               0.083333
# % Asian raw value                                           -0.492242
# % Native Hawaiian/Other Pacific Islander raw value          -0.233433
# % Hispanic raw value                                        -0.313305
# % Non-Hispanic white raw value                               0.329504
# % not proficient in English raw value                       -0.352240
# % Females raw value                                         -0.156169
# % Rural raw value                                            1.000000
# target                                                       0.216978
#
#                                                       target
# Poor or fair health raw value                      -0.117236
# Poor physical health days raw value                -0.094063
# Poor mental health days raw value                  -0.108632
# Adult smoking raw value                            -0.023481
# Adult obesity raw value                             0.019938
# Food environment index raw value                    0.185029
# Physical inactivity raw value                       0.068713
# Access to exercise opportunities raw value         -0.113876
# Excessive drinking raw value                        0.045189
# Alcohol-impaired driving deaths raw value          -0.021106
# Uninsured raw value                                -0.054936
# Dentists raw value                                 -0.149289
# Preventable hospital stays raw value                0.028715
# Mammography screening raw value                     0.040166
# Flu vaccinations raw value                          0.012338
# High school graduation raw value                    0.730025
# Some college raw value                              0.037253
# Unemployment raw value                             -0.168447
# Children in poverty raw value                      -0.185309
# Income inequality raw value                        -0.191224
# Children in single-parent households raw value     -0.320836
# Social associations raw value                       0.158073
# Air pollution - particulate matter raw value        0.078506
# Drinking water violations raw value                -0.034098
# Severe housing problems raw value                  -0.314685
# Percentage of households with high housing costs   -0.305863
# Percentage of households with overcrowding         -0.168300
# Percentage of households with lack of kitchen o...  0.005729
# Driving alone to work raw value                     0.074087
# Long commute - driving alone raw value              0.080373
# Life expectancy raw value                           0.056848
# Premature age-adjusted mortality raw value         -0.079417
# Frequent physical distress raw value               -0.115099
# Frequent mental distress raw value                 -0.135545
# Diabetes prevalence raw value                       0.023384
# Food insecurity raw value                          -0.185363
# Limited access to healthy foods raw value          -0.098926
# Insufficient sleep raw value                       -0.089993
# Uninsured adults raw value                         -0.083390
# Uninsured children raw value                        0.112653
# Other primary care providers raw value             -0.110172
# Median household income raw value                   0.096957
# Homeownership raw value                             0.271969
# Severe housing cost burden raw value               -0.301799
# Population raw value                               -0.126935
# % below 18 years of age raw value                   0.007102
# % 65 and older raw value                            0.090297
# % Non-Hispanic African American raw value          -0.247324
# % American Indian and Alaskan Native raw value     -0.147828
# % Asian raw value                                  -0.106601
# % Native Hawaiian/Other Pacific Islander raw value -0.140076
# % Hispanic raw value                               -0.092684
# % Non-Hispanic white raw value                      0.310942
# % not proficient in English raw value              -0.102636
# % Females raw value                                -0.037124
# % Rural raw value                                   0.216978
# target                                              1.000000
#
# [57 rows x 57 columns]

# %%
df['target'].value_counts().sort_index()
# Out:
# 0    1496
# 1    1318
# Name: target, dtype: int64

# %%
len(df.columns)
# Out:
# 64

# %%
# Making predictors and predictions
X = df.iloc[:, 6:]

# %%
# Making features and target
X.drop(columns=['High school graduation raw value', 'target'], inplace=True)
X = X.values
y = df['target'].values

# %%
# train, test, split variables
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10, test_size = 0.2)

# %%
# Scaling data
standard = StandardScaler()
X_train_scaled = standard.fit_transform(X_train)
X_test_scaled = standard.fit_transform(X_test)
X_scaled = standard.fit_transform(X)

# %%
# PCA components for training data
pca = PCA(0.99)
X_pca_train = pca.fit_transform(X_train_scaled)

PC1_train, PC2_train = X_pca_train[:, 0], X_pca_train[:, 1]

# %%
# PCA components for testing data
pca = PCA(0.99)
X_pca_test = pca.fit_transform(X_test_scaled)

PC1_test, PC2_test = X_pca_test[:, 0], X_pca_test[:, 1]

# %%
# PCA components for all data
pca = PCA(0.99)
X_pca = pca.fit_transform(X_scaled)

# Grabbing the first two PCs
PC1, PC2 = X_pca[:, 0], X_pca[:, 1]

# %%
pca_length = len(pca.explained_variance_ratio_.cumsum())

# %%
# Plot PCA CDF
plt.figure(figsize=(15,10))
plt.scatter(range(1,pca_length+1), pca.explained_variance_ratio_.cumsum())
plt.title('Total Variance Explained by Varying Number of Principle Components', fontsize=20);
plt.xlabel('Number of Principle Components', fontsize=20)
plt.ylabel('Variance of Dataset', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig('PCA1_raw_data.png')

# %%
pca.explained_variance_ratio_.cumsum()[:42] # the first 42 PC's capture 99% of data
# Out:
# array([0.28511022, 0.41529116, 0.50510692, 0.55887482, 0.59829165,
#        0.63336589, 0.65966897, 0.68356388, 0.70419218, 0.72387991,
#        0.74337356, 0.76167065, 0.77908316, 0.79514415, 0.81032313,
#        0.82466528, 0.83775027, 0.85011977, 0.86124768, 0.8721881 ,
#        0.88203296, 0.89165498, 0.90082107, 0.90921115, 0.91716529,
#        0.9245435 , 0.93139292, 0.93814322, 0.94434077, 0.9501076 ,
#        0.95497222, 0.95960744, 0.96388261, 0.96783441, 0.97164145,
#        0.9752804 , 0.97842332, 0.98142015, 0.98414984, 0.98664598,
#        0.98899019, 0.99113443])

# %%
# Creating a PCA dataframe with all data to observe how it splits the groups
# This is needed for the following plot
PCA_df = pd.DataFrame(X_pca)
y = pd.Series(y)

# %%
PCA_df['target'] = y
col_labels = ['PC' + str(x) for x in range(1,43)]
col_labels.append('target')
PCA_df.columns = col_labels
PCA_df['target'] = PCA_df['target'].astype('int')

# %%
PCA_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  1.225455 -0.592249 -2.057788 -1.744255  0.851220 -0.543019  0.946371
# 1 -1.139647 -0.132044 -1.613051 -0.733655 -0.749346  0.153310 -0.303816
# 2  7.495543  0.729164 -1.833153  0.422528 -0.171613 -2.202490  0.860262
# 3  3.266068 -2.945267 -1.479683 -1.981063  0.001725 -0.543432  0.732108
# 4  2.245427 -2.880771 -0.096666 -3.295468 -1.253140  0.874892  0.494026
#
#         PC8       PC9      PC10  ...      PC34      PC35      PC36      PC37  \
# 0  0.086140 -0.043791 -0.046675  ... -0.032144  0.112357 -0.214886 -0.466523
# 1  1.059109 -1.295496 -0.101730  ...  0.181366  0.309521 -0.086190 -0.361514
# 2 -2.430310 -0.985790  0.069543  ... -0.780535  0.729629 -0.069542  0.383126
# 3 -1.493161  0.687891  1.431809  ...  0.503011  0.178316 -0.581392 -0.382578
# 4  0.862430  0.473495  0.301224  ... -0.013054  0.359749  0.228112 -0.290534
#
#        PC38      PC39      PC40      PC41      PC42  target
# 0  0.244449 -0.177653  0.034748 -0.188026 -0.197052       1
# 1 -0.207823 -0.081647 -0.101893 -0.135956 -0.146207       0
# 2 -0.046955 -0.640849  0.494529 -0.173417  0.281804       0
# 3  0.322463 -0.159649 -0.238759 -0.029738  0.416205       0
# 4 -0.282478  0.421464  0.205084 -0.257438  0.246369       1
#
# [5 rows x 43 columns]

# %%
target = PCA_df['target']

# %%
fig = plt.figure(figsize = (15,10))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
targets = [0, 1]
labels = ['NOT meeting standard', 'Meeting Standard']
colors = ['orange', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = PCA_df['target'] == target
    ax.scatter(PCA_df.loc[indicesToKeep, 'PC1']
               , PCA_df.loc[indicesToKeep, 'PC2']
               , c = color
               , s = 50)
ax.legend(labels, fontsize=20, frameon=True, framealpha=1, edgecolor='k')
ax.grid()
plt.savefig('PCA2_first_two_comps_plot.png')

# %% [markdown]
# # Random Forest

# %%
# First running a random forest on our actual data
clf = RandomForestClassifier()
clf.fit(X_train_scaled, y_train)
y_pred = clf.predict(X_test_scaled)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6927175843694494

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[227,  68],
#        [105, 163]])

# %%
# Instantiate the visualizer with the classification model
plt.figure(figsize=(20,10))
visualizer = ROCAUC(clf)
visualizer.score(X_test, y_test)  # Evaluate the model on the test data

visualizer.poof()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.77      0.72       295
#            1       0.71      0.61      0.65       268
#
#     accuracy                           0.69       563
#    macro avg       0.69      0.69      0.69       563
# weighted avg       0.69      0.69      0.69       563

# %%
X_pca_train_random_forest = X_pca_train[:, :-1]

# %%
# Trying again, but this time with PC's
# X_pca_train has 42 columns while X_pca_test has 41. 
# This throws an error.
# Dropping one of the PC's from X_pca_train to geet around this

clf = RandomForestClassifier()
clf.fit(X_pca_train_random_forest, y_train)
y_pred = clf.predict(X_pca_test)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
plt.figure(figsize=(20,10))
visualizer = ROCAUC(clf)
visualizer.score(X_pca_test, y_test)  # Evaluate the model on the test data
visualizer.poof()

# %%
plt.figure(figsize=(15,10))
cm = ConfusionMatrix(clf)

# To create the ConfusionMatrix, we need some test data. Score runs predict() on the data
# and then creates the confusion_matrix from scikit-learn.
cm.score(X_pca_test, y_test)

# How did we do?
cm.poof()

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5861456483126111

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.77      0.66       295
#            1       0.60      0.38      0.47       268
#
#     accuracy                           0.59       563
#    macro avg       0.59      0.58      0.56       563
# weighted avg       0.59      0.59      0.57       563

# %%
steps = [('forest', RandomForestClassifier())]
pipe = Pipeline(steps=steps)

grid = {'forest__n_estimators': list(np.arange(1, 300, 20)),
        'forest__criterion': ['gini', 'entropy'],
        'forest__max_depth': list(np.arange(1, 7, 1)),
        'forest__max_leaf_nodes': list(np.arange(2, 100, 10)),
        'forest__random_state' : [0]}

gs = GridSearchCV(pipe, grid, cv=5, scoring='accuracy')


gs.fit(X_train_scaled, y_train)
gs.score(X_test_scaled, y_test)
gs.best_params_
# Out:
# {'forest__criterion': 'entropy',
#  'forest__max_depth': 6,
#  'forest__max_leaf_nodes': 52,
#  'forest__n_estimators': 221,
#  'forest__random_state': 0}

# %%
# First running a random forest on our actual data
clf = RandomForestClassifier(criterion='entropy', max_depth=6, max_leaf_nodes=52, n_estimators=221)
clf.fit(X_train_scaled, y_train)
y_pred = clf.predict(X_test_scaled)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7460035523978685

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       295
#            1       0.74      0.73      0.73       268
#
#     accuracy                           0.75       563
#    macro avg       0.75      0.75      0.75       563
# weighted avg       0.75      0.75      0.75       563

# %%
# Instantiate the visualizer with the classification model
plt.figure(figsize=(20,10))
visualizer = ROCAUC(clf)
visualizer.score(X_test, y_test)  # Evaluate the model on the test data

visualizer.poof()

# %%
plt.figure(figsize=(15,10))
cm = ConfusionMatrix(clf)

# To create the ConfusionMatrix, we need some test data. Score runs predict() on the data
# and then creates the confusion_matrix from scikit-learn.
cm.score(X_test, y_test)

# How did we do?
cm.poof()
